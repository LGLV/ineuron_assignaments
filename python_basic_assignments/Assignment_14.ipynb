# %% [markdown]
# <a href="https://colab.research.google.com/github/LGLV/ineuron_assignaments/blob/main/Assignment_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. What does RGBA stand for?**
#
# * RGBA is a four-channel format containing data for Red, Green, Blue, and an Alpha value. Where Alpha Represents the Opacity

# %% [markdown]
# **2. From the Pillow module, how do you get the RGBA value of any images?**
# * ImageColor.getcolor() gives rgba value of any image

# %% [markdown]
# **3. What is a box tuple, and how does it work?**
#
# * A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height, respectively.

# %% [markdown]
# **4. Use your image and load in notebook then, How can you find out the width and height of an Image object?**

# %%
#Example 
from PIL import Image
pic = Image.open('flower.jpg')
print(f'Width, Height -> {pic.size}') # Approach 1
print(f'Width, Height -> {pic.width},{pic.height}') # Approach 2
width,height = pic.size
print(f'Width, Height -> {width},{height}') # Approach 3
# Out:
# Width, Height -> (640, 427)
# Width, Height -> 640,427
# Width, Height -> 640,427

# %% [markdown]
# **5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?**

# %%
from PIL import Image
img = Image.open('flower.jpg')
new_img = img.crop((0,50,50,50))
img
# print(new_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x7FB5C207F730>

# %% [markdown]
# **6. After making changes to an Image object, how could you save it as an image file?**

# %%
#Example 
from PIL import Image
pic = Image.open('flower.jpg')
pic.save('flower2.jpg')

# %%
pic2 = Image.open('flower2.jpg')
pic2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x7FB5C200A4D0>

# %% [markdown]
# **7. What module contains Pillow’s shape-drawing code?**
#
# * Pillows ImageDraw module contains Shape drawing methods.

# %% [markdown]
# **8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?**
#
# * ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle().They are returned by passing the Image object to the ImageDraw.Draw() function.
